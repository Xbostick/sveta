# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
labels = {
    0: 'Bone',
    # 1: 'Fat',
    1: 'Palm_hypotenar',
    # 3: 'Palm_middle',
    2: 'Palm_tenar',
    3: 'Sub_Vein',
    4: 'Wrist_1',
    5: 'Wrist_2',
    6: 'Wrist_3'
}

# %%
dataF = pd.DataFrame()
for cl in labels.keys():
    data = pd.read_csv('./Data/'+labels[cl]+'.txt', sep='\t')
    data = data.iloc[:,2:-38]
    print(len(data)) #  размер классов
    data = data.assign(label = cl)
    dataF = pd.concat([dataF,data])
dataF.head()
# Out:
# 1246
# 820
# 1244
# 850
# 1592
# 1250
# 1240
#        AC 1 A     AC 2 A      AC 3 A     AC 4 A      AC 5 A     AC 6 A  \
# 0  130.635160  32.192296  150.286531  35.907402  223.849355  36.603935
# 1  130.674017  32.288870  150.450092  35.832822  223.903515  36.645455
# 2  130.834885  32.383223  150.766170  35.902829  223.830800  36.581942
# 3  130.848810  32.408946  150.718116  35.952093  223.800249  36.722004
# 4  131.100286  32.389032  150.786570  35.992579  224.203375  36.734965
#
#        AC 7 A     AC 8 A      DC 1 A      DC 2 A      DC 3 A      DC 4 A  \
# 0  197.086938  59.920016  820.033687  213.116277  943.505729  234.692968
# 1  197.237593  59.876467  819.867704  213.255077  944.264392  234.732417
# 2  197.334851  59.988612  820.899926  213.659216  945.359731  235.014591
# 3  197.339905  59.962161  821.580587  213.933801  945.743418  235.094588
# 4  197.446393  60.119024  822.433247  214.011900  946.601336  235.503427
#
#         DC 5 A      DC 6 A       DC 7 A      DC 8 A  label
# 0  1344.327205  217.952968  1146.539527  355.886738      0
# 1  1344.122496  218.021736  1147.018345  356.171297      0
# 2  1344.461563  218.186490  1147.510903  356.130436      0
# 3  1344.212198  218.321068  1147.648433  356.325055      0
# 4  1344.822910  218.446980  1148.919687  356.735438      0

# %%
dataF[dataF['label'] == 0 ]
# Out:
#           AC 1 A     AC 2 A      AC 3 A     AC 4 A      AC 5 A     AC 6 A  \
# 0     130.635160  32.192296  150.286531  35.907402  223.849355  36.603935
# 1     130.674017  32.288870  150.450092  35.832822  223.903515  36.645455
# 2     130.834885  32.383223  150.766170  35.902829  223.830800  36.581942
# 3     130.848810  32.408946  150.718116  35.952093  223.800249  36.722004
# 4     131.100286  32.389032  150.786570  35.992579  224.203375  36.734965
# ...          ...        ...         ...        ...         ...        ...
# 1241  123.374059  31.182948  146.975813  34.959581  214.278570  35.413273
# 1242  123.147957  31.083033  146.938743  35.003904  214.138800  35.453422
# 1243  123.306947  31.129867  147.301600  35.140712  214.212174  35.443774
# 1244  123.427667  31.243871  147.521295  35.202999  214.399012  35.532018
# 1245  123.553009  31.308850  147.727018  35.236914  214.543019  35.552176
#
#           AC 7 A     AC 8 A      DC 1 A      DC 2 A      DC 3 A      DC 4 A  \
# 0     197.086938  59.920016  820.033687  213.116277  943.505729  234.692968
# 1     197.237593  59.876467  819.867704  213.255077  944.264392  234.732417
# 2     197.334851  59.988612  820.899926  213.659216  945.359731  235.014591
# 3     197.339905  59.962161  821.580587  213.933801  945.743418  235.094588
# 4     197.446393  60.119024  822.433247  214.011900  946.601336  235.503427
# ...          ...        ...         ...         ...         ...         ...
# 1241  192.030042  57.983914  774.803280  206.198621  922.702025  229.220721
# 1242  191.877157  57.991407  773.493312  205.901357  922.263970  229.071846
# 1243  192.178572  58.086667  774.731916  206.455112  924.582564  229.685572
# 1244  192.145916  58.118097  775.356611  206.848325  925.718898  230.030606
# 1245  192.475836  58.125172  776.456794  207.190977  926.946729  230.449762
#
#            DC 5 A      DC 6 A       DC 7 A      DC 8 A  label
# 0     1344.327205  217.952968  1146.539527  355.886738      0
# 1     1344.122496  218.021736  1147.018345  356.171297      0
# 2     1344.461563  218.186490  1147.510903  356.130436      0
# 3     1344.212198  218.321068  1147.648433  356.325055      0
# 4     1344.822910  218.446980  1148.919687  356.735438      0
# ...           ...         ...          ...         ...    ...
# 1241  1286.136223  211.222573  1117.385385  344.531598      0
# 1242  1285.552329  211.102695  1117.116425  344.484508      0
# 1243  1286.614798  211.504665  1118.137313  344.853511      0
# 1244  1287.711992  211.809680  1118.702344  345.079426      0
# 1245  1288.788565  212.105519  1120.092412  345.529066      0
#
# [1246 rows x 17 columns]

# %%
cl = dataF[dataF['label'] == 0 ]

# %%
cl.iloc[:,0]
# Out:
# 0       130.635160
# 1       130.674017
# 2       130.834885
# 3       130.848810
# 4       131.100286
#            ...
# 1241    123.374059
# 1242    123.147957
# 1243    123.306947
# 1244    123.427667
# 1245    123.553009
# Name: AC 1 A, Length: 1246, dtype: float64

# %%
dataF.shape
# Out:
# (8242, 17)

# %%
import math

dataFNN = pd.DataFrame()
Test_Period_len = 10
for cl in labels.keys():
    data = pd.read_csv('./Data/'+labels[cl]+'.txt', sep='\t')
    data = data.iloc[:,2:-38]
    raw = []
    for i in range(math.floor(data.shape[0])):
        if (i + 10 <= math.floor(data.shape[0])):
            a = data.iloc[i:i+10,:].values
            a = a.reshape(160,1)
            #print(a)
            a = np.append(a,cl)
            #print(a)
            raw.append(a)
            #print(raw)
    dataFNN = pd.concat([dataFNN,pd.DataFrame(raw)],axis = 0)
    print(1)
dataFNN.head()
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1
#           0          1           2          3           4          5    \
# 0  130.635160  32.192296  150.286531  35.907402  223.849355  36.603935
# 1  130.674017  32.288870  150.450092  35.832822  223.903515  36.645455
# 2  130.834885  32.383223  150.766170  35.902829  223.830800  36.581942
# 3  130.848810  32.408946  150.718116  35.952093  223.800249  36.722004
# 4  131.100286  32.389032  150.786570  35.992579  224.203375  36.734965
#
#           6          7           8           9    ...        151         152  \
# 0  197.086938  59.920016  820.033687  213.116277  ...  60.016853  818.501781
# 1  197.237593  59.876467  819.867704  213.255077  ...  60.053784  818.874536
# 2  197.334851  59.988612  820.899926  213.659216  ...  60.151338  820.343118
# 3  197.339905  59.962161  821.580587  213.933801  ...  59.994442  820.580636
# 4  197.446393  60.119024  822.433247  214.011900  ...  60.061099  821.518472
#
#           153         154         155          156         157          158  \
# 0  212.753195  943.860500  234.542623  1340.222252  217.564718  1146.133060
# 1  212.809661  942.848067  234.576802  1340.536552  217.640169  1146.743431
# 2  213.404299  944.060085  234.942880  1341.845044  218.019287  1148.126495
# 3  213.359902  944.021090  234.763371  1340.758612  217.844403  1147.617247
# 4  213.671341  945.736024  235.343392  1342.385527  218.063235  1148.441234
#
#           159  160
# 0  356.088312  0.0
# 1  356.321316  0.0
# 2  356.670388  0.0
# 3  356.519717  0.0
# 4  356.735975  0.0
#
# [5 rows x 161 columns]

# %%
a = dataFNN.iloc[:,:-1]

# %%
dataFNN.index = range(dataFNN.shape[0])

# %%
a.iloc[1,:]
# Out:
# 0       130.674017
# 1        32.288870
# 2       150.450092
# 3        35.832822
# 4       223.903515
#           ...
# 155     234.576802
# 156    1340.536552
# 157     217.640169
# 158    1146.743431
# 159     356.321316
# Name: 1, Length: 160, dtype: float64

# %%
a
# Out:
#              0          1           2          3           4          5    \
# 0     130.635160  32.192296  150.286531  35.907402  223.849355  36.603935
# 1     130.674017  32.288870  150.450092  35.832822  223.903515  36.645455
# 2     130.834885  32.383223  150.766170  35.902829  223.830800  36.581942
# 3     130.848810  32.408946  150.718116  35.952093  223.800249  36.722004
# 4     131.100286  32.389032  150.786570  35.992579  224.203375  36.734965
# ...          ...        ...         ...        ...         ...        ...
# 1226   91.729460  24.223951   45.130140  10.100147  145.666177  32.728692
# 1227   91.899255  24.310782   45.428591  10.266663  145.728473  32.821155
# 1228   91.956278  24.333502   45.720782  10.363080  145.900984  32.801400
# 1229   92.404055  24.613691   46.038172  10.511719  146.478808  33.139824
# 1230   92.515325  24.569355   45.794562  10.397448  146.380892  33.068610
#
#              6          7           8           9    ...         150  \
# 0     197.086938  59.920016  820.033687  213.116277  ...  197.027531
# 1     197.237593  59.876467  819.867704  213.255077  ...  197.109558
# 2     197.334851  59.988612  820.899926  213.659216  ...  197.507274
# 3     197.339905  59.962161  821.580587  213.933801  ...  197.366318
# 4     197.446393  60.119024  822.433247  214.011900  ...  197.661675
# ...          ...        ...         ...         ...  ...         ...
# 1226   67.001601  21.883410  732.174752  200.204985  ...   67.200797
# 1227   67.700598  22.163381  733.016004  200.143992  ...   67.685707
# 1228   68.041079  22.307529  734.191650  200.938135  ...   68.003630
# 1229   68.529959  22.537672  737.760061  202.655643  ...   68.491975
# 1230   67.679057  22.260579  738.250117  202.665654  ...   66.849580
#
#             151         152         153         154         155          156  \
# 0     60.016853  818.501781  212.753195  943.860500  234.542623  1340.222252
# 1     60.053784  818.874536  212.809661  942.848067  234.576802  1340.536552
# 2     60.151338  820.343118  213.404299  944.060085  234.942880  1341.845044
# 3     59.994442  820.580636  213.359902  944.021090  234.763371  1340.758612
# 4     60.061099  821.518472  213.671341  945.736024  235.343392  1342.385527
# ...         ...         ...         ...         ...         ...          ...
# 1226  22.065369  731.808086  198.791006  366.147863   87.744847  1119.868157
# 1227  22.237329  732.256121  199.052307  368.518982   88.464934  1120.531456
# 1228  22.290681  732.965565  199.783383  369.954487   88.975944  1121.594755
# 1229  22.367497  733.550155  199.773263  371.798197   89.582626  1121.441094
# 1230  21.942546  734.497848  200.623454  366.172704   87.566556  1123.921108
#
#              157          158         159
# 0     217.564718  1146.133060  356.088312
# 1     217.640169  1146.743431  356.321316
# 2     218.019287  1148.126495  356.670388
# 3     217.844403  1147.617247  356.519717
# 4     218.063235  1148.441234  356.735975
# ...          ...          ...         ...
# 1226  243.339849   507.312611  169.401402
# 1227  243.635078   510.609761  170.511267
# 1228  244.054234   512.654398  171.264079
# 1229  244.151409   515.493862  172.011007
# 1230  244.616236   504.073306  168.701177
#
# [8179 rows x 160 columns]

# %%
import torch
from torch.utils.data import Dataset, DataLoader,TensorDataset
from torch import nn
from torch.nn import functional as F

# %%
class My_dataset (Dataset):
    def __init__(self,DF):
        self.__labels = DF.iloc[:,-1]
        self.__features = DF.iloc[:,:-1]

    def __len__(self):
        return self.__labels.shape[0]

    def __getitem__(self, index):
        return self.__features.iloc[index,:], self.__labels[index]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(dataFNN.iloc[:,:-1], dataFNN.iloc[:,-1], random_state = 20)

# %%
type(torch.tensor(X_train.values))
# Out:
# torch.Tensor

# %%
train_dataset = TensorDataset(torch.tensor(X_train.values),torch.tensor(Y_train.values))
test_dataset = TensorDataset(torch.tensor(X_test.values),torch.tensor(Y_test.values))
train_dataloader = DataLoader(train_dataset, batch_size = 1)
test_dataloader = DataLoader(test_dataset, batch_size = 1)

# %%
ds = My_dataset(dataFNN)
data_loader = DataLoader(ds, batch_size=600, shuffle=True)

# %%
data = My_dataset(dataFNN)

# %%
data.__getitem__(3)
# Out:
# (0       130.848810
#  1        32.408946
#  2       150.718116
#  3        35.952093
#  4       223.800249
#            ...
#  155     234.763371
#  156    1340.758612
#  157     217.844403
#  158    1147.617247
#  159     356.519717
#  Name: 3, Length: 160, dtype: float64,
#  0.0)

# %%
class Identical(nn.Module):
    def forward(self,x):
        return x

# %%
activation = nn.ELU

model = nn.Sequential(
    #nn.Flatten(),
    torch.nn.Linear(160, 120),
    activation(),
    torch.nn.Linear(120, 30),
    activation(),
    torch.nn.Linear(30, 6),
    torch.nn.Softmax()
)

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader,"test" : test_dataloader}

# %%
max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in range(max_epochs):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0
        for x_batch, y_batch in dataloader:
            #x_batch,y_batch = x_batch.cuda(), y_batch.cuda()
            print(x_batch.shape)
            if k == "train":
                model.train() 
                optimizer.zero_grad()
                outp = model(x_batch.transpose)
            else:
                 model.eval()
                 with torch.no_grad():
                   outp = model(x_batch)
            preds = outp.argmax(-1)
            correct =  (preds.flatten() == y_batch).type(torch.float32).sum()
            all =  y_batch.size(0)
            epoch_correct += correct.item()
            epoch_all += all
            if k == "train":
                loss = criterion(outp, y_batch)
                loss.backward()
                optimizer.step()
        if k == "train":
            print(f"Epoch: {epoch+1}")
        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct/epoch_all)
# Out:
# torch.Size([1, 160])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [276], line 13
#      11     model.train()
#      12     optimizer.zero_grad()
# ---> 13     outp = model(x_batch.transpose)
#      14 else:
#      15      model.eval()
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# TypeError: linear(): argument 'input' (position 1) must be Tensor, not builtin_function_or_method

# %%
Y = dataF['label']
X = dataF.drop('label', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.1,random_state=15)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,DT.predict_proba(X_test),multi_class = 'ovr' )
# Out:
# 1.0

# %%
data_p = pd.read_csv('/Users/aleksandr/Desktop/HSE/ML/sveta/19.05/slpArm6.txt', sep='\t')
data_p = data_p.iloc[:,2:-38] 

pred = DT.predict(data_p)
labels[round(np.mean(pred))]
# Out:
# 'Wrist_2'

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
roc_auc_score(Y_test,RF.predict_proba(X_test),multi_class = 'ovr' )
# Out:
# 1.0

# %%
pred_RF = RF.predict(X_test)

# %%
data_RF = pd.read_csv('/Users/aleksandr/Desktop/HSE/ML/sveta/19.05/bpvArm2.txt', sep='\t')
data_RF = data_RF.iloc[:,2:-38] 

pred_data_RF = DT.predict_proba(data_RF)
print(sum(pred_data_RF))
cl = np.where(sum(pred_data_RF) == max(sum(pred_data_RF)))
print(labels[cl[0][0]])
# Out:
# [   0.    0.    0.    0.    0.    0. 4950.]
# Wrist_3

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

LR = LogisticRegression(max_iter = 1000).fit(X_train, Y_train)

print("Accuracy")
for name, x, y in ('train', X_train, Y_train), ('test', X_test, Y_test):
  predict = LR.predict(x)
  accuracy = accuracy_score(y, predict)
  print(f"\t{name}: {accuracy:.2f}")
# Out:
# Accuracy
# 	train: 1.00
# 	test: 1.00

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

SV = SVC(C = 1, gamma = 'scale',kernel = 'linear',probability = True)
SV.fit(X_train,Y_train)
# Out:
# SVC(C=1, kernel='linear', probability=True)

# %%
print(f"Score: {roc_auc_score(Y_test,SV.predict_proba(X_test), multi_class = 'ovr')}")
# Out:
# Score: 1.0

# %%
grid = {
    'C': [1, 10, 100, 1000],  
    'gamma': ['scale', 'auto'], 
    'kernel': ['linear', 'sigmoid', 'rbf','poly']
}

# scoring-parameter
grid_search = GridSearchCV(SVC(), grid, cv=5, scoring='f1')
grid_search.fit(X_train,Y_train)

grid_search.best_params_
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
# ...
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 267, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1136, in f1_score
#     return fbeta_score(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1277, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1563, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1381, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
W1 = pd.read_csv('./Data/Wrist_3.txt', sep='\t')
Slp_A2 = pd.read_csv('./19.05/bpvArm6.txt', sep='\t')
x = W1.iloc[200:600,1]
y1 = W1.iloc[200:600,2:6]
y2 = Slp_A2.iloc[200:600,2:6]

fig, axs = plt.subplots(2, 1)
axs[0].plot(x, y1)
axs[1].plot(x, y2)
axs[0].set_xlabel('Time')
axs[0].set_ylabel('y1')
axs[0].grid(True)
axs[1].grid(True)
axs[1].set_ylabel('y2')

fig.tight_layout()
plt.show()

# %% [markdown]
# Нейро-сеть
